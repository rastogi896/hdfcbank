# %%
import pandas as pd

# %%
AggregateData_Train=pd.read_csv("AggregateData_Train.csv")

# %%
AggregateData_Train.head()
# Out:
#     UID           V2        V3      V4      V5 V6     V7 V8   V9        V10  \
# 0  Tr-1  61P4S1M3GET  10397.75       ?       ?  ?      ?  ?    ?  197186.68
# 1  Tr-2  6NYVS1J3U7M         ?  606.74       ?  ?      ?  ?    ?          ?
# 2  Tr-3   BLFB1KMS48  87452.89  963.52       ?  ?  13838  ?    ?    1081.25
# 3  Tr-4   MYGB1LCW8P         ?  393.26  100000  ?      ?  ?    ?          ?
# 4  Tr-5  6UG5S1PQGE5      1100   497.2       ?  ?      ?  ?  0.9      18640
#
#     ...    V45      V46 V47 V48      V49 V50 V51 V52 V53 bad_flag
# 0   ...      ?  5.04055   ?   ?        ?   6   9   3  10        0
# 1   ...      ?        ?   ?   ?        ?   1   ?   ?   ?        0
# 2   ...      ?        ?   ?   ?        ?  10  10  20   1        0
# 3   ...      ?        ?   ?   ?        ?   4   1   ?   2        0
# 4   ...      ?  0.00470   ?   ?  0.00007   2   3   1   2        0
#
# [5 rows x 54 columns]

# %%
AggregateData_Train.shape
# Out:
# (26775, 54)

# %%
AggregateData_Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26775 entries, 0 to 26774
# Data columns (total 54 columns):
# UID         26775 non-null object
# V2          26775 non-null object
# V3          26775 non-null object
# V4          26775 non-null object
# V5          26775 non-null object
# V6          26775 non-null object
# V7          26775 non-null object
# V8          26775 non-null object
# V9          26775 non-null object
# V10         26775 non-null object
# V11         26775 non-null object
# V12         26775 non-null object
# V13         26775 non-null object
# V14         26775 non-null object
# V15         26775 non-null object
# V16         26775 non-null object
# V17         26775 non-null object
# V18         26775 non-null object
# V19         26775 non-null object
# V20         26775 non-null object
# V21         26775 non-null object
# V22         26775 non-null object
# V23         26775 non-null object
# V24         26775 non-null object
# ...

# %%
sample_submission=pd.read_csv("sample_submission.csv")
sample_submission.shape
# Out:
# (10, 2)

# %%
sample_submission
# Out:
#      UID  bad_flag
# 0   Te-1  0.054400
# 1   Te-2  0.084719
# 2   Te-3  0.049044
# 3   Te-4  0.095034
# 4   Te-5  0.065099
# 5   Te-6  0.034086
# 6   Te-7  0.025697
# 7   Te-8  0.076009
# 8   Te-9  0.117930
# 9  Te-10  0.051464

# %%
TransactionData_Train=pd.read_csv("TransactionData_Train.csv")
TransactionData_Train.shape
# Out:
# (3343745, 9)

# %%
AggregateData_Test=pd.read_csv("AggregateData_Test.csv")
AggregateData_Test.shape
# Out:
# (48434, 53)

# %%
TransactionData_Test=pd.read_csv("TransactionData_Test.csv")
TransactionData_Test.shape
# Out:
# (2648039, 9)

# %%
TransactionData_Train.head()
# Out:
#              C2               C3                C4 C5   C6          C8  \
# 0  6UGH4BMM1Y6P  6YPV4HMP1V5EWID  06JUL38:17:31:02  D  IAD  2038-12-30
# 1   9Y46ZBCWRP9  61CE41JD5YMP329  05MAY38:16:46:36  D  STD  2039-06-31
# 2   6Z4F3BPVME6  6UQA3CP9F95BOBD  08FEB37:15:55:28  C  OCD  2038-04-31
# 3  6UYF21TDMPPT   BZF6Z3AJQ55MAM  24NOV38:09:48:37  D  EAW  2039-05-29
# 4   5N5ASLGMMPM  6IPA43AM4Y613SX  26OCT38:18:54:06  D  ATW  2038-03-31
#
#                  C9    C10      C12
# 0  30JUL38:00:00:00  OTHER  22000.0
# 1  28MAY38:00:00:00     FT   8183.0
# 2  30FEB37:00:00:00    CHQ  48900.0
# 3  31NOV38:00:00:00    ATM   1500.0
# 4  31OCT38:00:00:00    ATM  10000.0

# %%
TransactionData_Test.head()
# Out:
#              C2               C3                C4 C5   C6          C8  \
# 0   IYH6EOT91IN  6I5V3CKDUVTER3U  16JAN37:23:42:31  D  RDD  2038-02-30
# 1  6NF44HKS8VNP  68BV39T3U86732X  01MAR37:10:24:25  D  NWD  2038-12-30
# 2  6LFE2QYJ56TM  6UHW3BHJGEWE93X  23APR38:09:33:09  C  MCR  2038-07-30
# 3  61QE4KT94V5N  6XBA4KPWF94NEBQ  30SEP38:17:30:56  D  ETD  2039-05-29
# 4  6XGA3KPVR7WH    5NFF4KADUV41J  23DEC37:19:37:08  C  OCD  2038-01-31
#
#                  C9    C10       C12
# 0  31JAN37:00:00:00  SWEEP   1000.00
# 1  31MAR37:00:00:00    ATM  10000.00
# 2  31APR38:00:00:00  OTHER  23591.24
# 3  30SEP38:00:00:00  OTHER  24000.00
# 4  30DEC37:00:00:00    CHQ   4076.00

# %%
print(set(TransactionData_Test['C5']))
print(set(TransactionData_Test['C10']))
# Out:
# {'C', 'D'}
# {'ATM', 'NEFT', 'RTGS', 'CHG', 'FCC', 'TAX', 'FT', 'OTHER', 'CHQ', 'Interest', 'ECS', 'CMS', 'IMPS', 'Deal pro', 'ENET', 'SWEEP'}

# %%
print(set(TransactionData_Train['C5']))
print(set(TransactionData_Test['C10']))
# Out:
# {'C', 'D'}
# {'ATM', 'NEFT', 'RTGS', 'CHG', 'FCC', 'TAX', 'FT', 'OTHER', 'CHQ', 'Interest', 'ECS', 'CMS', 'IMPS', 'Deal pro', 'ENET', 'SWEEP'}

# %%
AggregateData_Test.head()
# Out:
#     UID           V2        V3      V4      V5 V6     V7 V8   V9        V10  \
# 0  Te-1  61P4S1M3GET  10397.75       ?       ?  ?      ?  ?    ?  197186.68
# 1  Te-2  6NYVS1J3U7M         ?  606.74       ?  ?      ?  ?    ?          ?
# 2  Te-3   BLFB1KMS48  87452.89  963.52       ?  ?  13838  ?    ?    1081.25
# 3  Te-4   MYGB1LCW8P         ?  393.26  100000  ?      ?  ?    ?          ?
# 4  Te-5  6UG5S1PQGE5      1100   497.2       ?  ?      ?  ?  0.9      18640
#
#   ...      V44 V45      V46 V47 V48      V49 V50 V51 V52 V53
# 0 ...        ?   ?  5.04055   ?   ?        ?   6   9   3  10
# 1 ...        ?   ?        ?   ?   ?        ?   1   ?   ?   ?
# 2 ...  1.28678   ?        ?   ?   ?        ?  10  10  20   1
# 3 ...        ?   ?        ?   ?   ?        ?   4   1   ?   2
# 4 ...        ?   ?  0.00470   ?   ?  0.00007   2   3   1   2
#
# [5 rows x 53 columns]

# %%
AggregateData_Test.describe()
# Out:
#              UID            V2     V3     V4     V5     V6     V7     V8  \
# count      48434         48434  48434  48434  48434  48434  48434  48434
# unique     48434         25719   9565  12664    648    980   1710     34
# top     Te-39137  61CW43PD8Y9P      ?      ?      ?      ?      ?      ?
# freq           1             8  28150   9912  47026  45905  44833  48371
#
#            V9    V10  ...      V44    V45    V46    V47    V48    V49    V50  \
# count   48434  48434  ...    48434  48434  48434  48434  48434  48434  48434
# unique    369   1654  ...     1914    686   4645    300     35    313    126
# top         ?      ?  ...        ?      ?      ?      ?      ?      ?      ?
# freq    47668  45067  ...    44833  47133  38942  47863  48371  47668  24491
#
#           V51    V52    V53
# count   48434  48434  48434
# unique    176    162    177
# top         ?      ?      ?
# freq    21297  29193  21590
#
# [4 rows x 53 columns]

# %%
AggregateData_Train.isnull().sum()
# Out:
# UID         0
# V2          0
# V3          0
# V4          0
# V5          0
# V6          0
# V7          0
# V8          0
# V9          0
# V10         0
# V11         0
# V12         0
# V13         0
# V14         0
# V15         0
# V16         0
# V17         0
# V18         0
# V19         0
# V20         0
# V21         0
# V22         0
# V23         0
# V24         0
# V25         0
# V26         0
# V27         0
# V28         0
# V29         0
# V30         0
# V31         0
# V32         0
# V33         0
# V34         0
# V35         0
# V36         0
# V37         0
# V38         0
# V39         0
# V40         0
# V41         0
# V42         0
# V43         0
# V44         0
# V45         0
# V46         0
# V47         0
# V48         0
# V49         0
# V50         0
# V51         0
# V52         0
# V53         0
# bad_flag    0
# dtype: int64

# %%
test_id = AggregateData_Test['UID']

# %%
y_train=AggregateData_Train['bad_flag']
y_train.shape
# Out:
# (26775,)

# %%
x_train=AggregateData_Train.drop(['UID','V2'],axis=1)
x_train.shape
# Out:
# (26775, 52)

# %%
x_train=x_train.drop(['bad_flag'],axis=1)

# %%
x_test=AggregateData_Test.drop(['UID','V2'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import ensemble

# %%
sc= StandardScaler()

# %%
clf = ensemble.GradientBoostingRegressor(n_estimators = 2000,max_features='log2', max_depth = 40, min_samples_split = 2,
          learning_rate = 0.8, loss = 'ls')

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()

# %%
x_train=x_train.apply(le.fit_transform)

# %%
x_train.head()
# Out:
#      V3     V4   V5   V6    V7  V8   V9   V10  V11  V12 ...    V44  V45   V46  \
# 0   167  12651  646  974  1707  33  367   539  990  669 ...   1911  684  4004
# 1  9553  10066  646  974  1707  33  367  1651  990  669 ...   1911  684  4633
# 2  9012  12445  646  974   269  33  367    78  746  422 ...   1583  684  4633
# 3  9553   7897    3  974  1707  33  367  1651  990  669 ...   1911  684  4633
# 4   413   9101  646  974  1707  33    0   499  990  669 ...   1911  684   308
#
#    V47  V48  V49  V50  V51  V52  V53
# 0  298   34  311   87  164   80    1
# 1  298   34  311    0  175  161  176
# 2  298   34  311    1    1   57    0
# 3  298   34  311   64    0  161   64
# 4  298   34    7   35   88    0   64
#
# [5 rows x 51 columns]

# %%
x_test=x_test.apply(le.fit_transform)

# %%
x_test.head()
# Out:
#      V3     V4   V5   V6    V7  V8   V9   V10  V11  V12 ...    V44  V45   V46  \
# 0   168  12663  647  979  1709  33  368   539  990  670 ...   1913  685  4012
# 1  9564  10073  647  979  1709  33  368  1653  990  670 ...   1913  685  4644
# 2  9023  12457  647  979   270  33  368    78  746  422 ...   1584  685  4644
# 3  9564   7905    3  979  1709  33  368  1653  990  670 ...   1913  685  4644
# 4   414   9107  647  979  1709  33    0   499  990  670 ...   1913  685   308
#
#    V47  V48  V49  V50  V51  V52  V53
# 0  299   34  312   87  164   80    1
# 1  299   34  312    0  175  161  176
# 2  299   34  312    1    1   57    0
# 3  299   34  312   64    0  161   64
# 4  299   34    7   35   88    0   64
#
# [5 rows x 51 columns]

# %%
x_train = sc.fit_transform(x_train)
x_test= sc.transform(x_test)
# Out:
# C:\Users\Deepak\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:617: DataConversionWarning: Data with input dtype int32 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\Deepak\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int32 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\Deepak\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int32 were all converted to float64 by StandardScaler.

# %%
clf.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.8, loss='ls', max_depth=40,
#              max_features='log2', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=1, min_samples_split=2,
#              min_weight_fraction_leaf=0.0, n_estimators=2000,
#              n_iter_no_change=None, presort='auto', random_state=None,
#              subsample=1.0, tol=0.0001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
pred=clf.predict(x_test)

# %%
print(type(pred))
# Out:
# <class 'numpy.ndarray'>

# %%
pred
# Out:
# array([-8.44766524e-06,  1.25499398e-05, -1.26401686e-06, ...,
#         2.55766762e-06, -2.27090854e-08,  1.07664244e-05])

# %%
import numpy as np

# %%
pred=pred.tolist()

# %%
pred
# Out:
# [-8.447665240605675e-06,
#  1.2549939760062694e-05,
#  -1.2640168636997523e-06,
#  -5.0651825195207356e-06,
#  9.634542058803416e-07,
#  2.624997489354662e-06,
#  1.9004965319555777e-09,
#  -3.909851740327477e-06,
#  1.0918098692681331e-05,
#  -0.0001283520539752239,
#  1.4500545456560441e-05,
#  1.5810003146049634e-07,
#  0.11547344108315394,
#  2.5858354491435994e-05,
#  -1.202472653826223e-06,
#  -2.435992788786949e-05,
#  8.63830814969134e-06,
#  -6.573630399999976e-06,
#  -6.356535578261461e-06,
#  0.00010257240863302402,
#  -1.035187438653128e-06,
#  3.2356658577662873e-06,
#  2.4864072540899676e-05,
#  -5.6997186754057274e-08,
#  7.337173018717254e-06,
#  -1.8413972259201036e-06,
#  -1.9381282960573368e-05,
#  3.8610742275268457e-05,
#  -4.493983040596641e-06,
#  1.647323379053931e-07,
#  -6.0228105256510635e-06,
#  1.1828865038356248e-05,
#  -2.0209949363048375e-06,
#  7.260817649656817e-07,
#  0.11547344108315394,
#  4.028066311088081e-09,
#  -1.590124519511411e-06,
# ...

# %%
columns = ['bad_flag']
sub = pd.DataFrame(data=pred, columns=columns)
sub['UID'] = test_id
sub = sub[['UID','bad_flag']]

# %%
sub
# Out:
#             UID      bad_flag
# 0          Te-1 -8.447665e-06
# 1          Te-2  1.254994e-05
# 2          Te-3 -1.264017e-06
# 3          Te-4 -5.065183e-06
# 4          Te-5  9.634542e-07
# 5          Te-6  2.624997e-06
# 6          Te-7  1.900497e-09
# 7          Te-8 -3.909852e-06
# 8          Te-9  1.091810e-05
# 9         Te-10 -1.283521e-04
# 10        Te-11  1.450055e-05
# 11        Te-12  1.581000e-07
# 12        Te-13  1.154734e-01
# 13        Te-14  2.585835e-05
# 14        Te-15 -1.202473e-06
# 15        Te-16 -2.435993e-05
# 16        Te-17  8.638308e-06
# 17        Te-18 -6.573630e-06
# 18        Te-19 -6.356536e-06
# 19        Te-20  1.025724e-04
# 20        Te-21 -1.035187e-06
# 21        Te-22  3.235666e-06
# 22        Te-23  2.486407e-05
# 23        Te-24 -5.699719e-08
# 24        Te-25  7.337173e-06
# 25        Te-26 -1.841397e-06
# 26        Te-27 -1.938128e-05
# 27        Te-28  3.861074e-05
# 28        Te-29 -4.493983e-06
# 29        Te-30  1.647323e-07
# ...

# %%
sub.to_csv("hdfc.csv", index=False)
